# %% [markdown]
# ### __Q.__ 숫자 집합 candidates를 조합하여 합이 target이 되는 원소를 나열하기
# - 각 원소는 중복으로 나열이 가능함

# %%
candidates = [2, 3, 6, 7]
target = [7]

# %%
class Solution:
  def combiSum(candidates, target):
    ans = []
    coms = []
    def dfs(nums, target):
      if target == 0:
        ans.append(coms[:])

      for i in range(len(nums)):
        if nums[i] > target:
          continue
        coms.append(nums[i])
        dfs(nums[i:], target - nums[i])
        coms.pop()
    dfs(candidates, target)

    return result
